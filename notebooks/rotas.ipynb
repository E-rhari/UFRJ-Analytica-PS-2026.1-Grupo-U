# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../datasets/routes.csv")
df.head()
# Out:
#   feed_version feed_start_date feed_end_date       route_id  agency_id  \
# 0   2024-07-22      2024-07-22    2024-07-26  20000EXEC1110      20001
# 1   2024-07-22      2024-07-22    2024-07-26     E2024AAA0A      22002
# 2   2024-07-22      2024-07-22    2024-07-26     O0553AAP0A      22004
# 3   2024-07-22      2024-07-22    2024-07-26     O0558AAA0A      22004
# 4   2024-07-22      2024-07-22    2024-07-26     O0552AAA0A      22004
#
#   route_short_name                         route_long_name      route_desc  \
# 0            ESP01             Galeão - Terminal Gentileza          Direto
# 1             2024  Leblon - Aeroporto Internacional do RJ          LECD71
# 2            SP553                     Barra Sul - Rio Sul  SP Integrada 8
# 3              558             Cidade de Deus - Copacabana     Integrada 6
# 4              552             Terminal Alvorada - Rio Sul     Integrada 2
#
#    route_type  route_url route_color route_text_color  route_sort_order  \
# ...

# %%
df = df[["route_id","route_long_name"]]

# %%
split_df = df['route_long_name'].str.split('-', expand=True)

# %%
k = split_df[2].value_counts()

# %%
print(k)
# Out:
# 2
# Manaceia    19
# Name: count, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 substring = 'tij'
# ----> 2 mask = np.char.find(k.astype(str), 'baixada') >= 0
#       3 print(mask)
#       4 print(arr[mask])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\numpy\_core\strings.py:306, in find(a, sub, start, end)
#     273 """
#     274 For each element, return the lowest index in the string where
#     275 substring ``sub`` is found, such that ``sub`` is contained in the
#    (...)    303
#     304 """
#     305 end = end if end is not None else MAX
# --> 306 return _find_ufunc(a, sub, start, end)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:952, in Index.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     949         return result
#     951 new_inputs = [x if x is not self else x._values for x in inputs]
# ...
